# %% [markdown]
# # Trusted zone - Household

# %%
import duckdb

# %%
con = duckdb.connect('household.duckdb')
data = con.execute("SELECT * FROM household").df()
con.close()

# %%
data #  ready to be pre-processed
# Out:
#                       section  total_2018  single_women_aged_16_to_64_2018  \
# 0            Ciudad de Madrid   1278258.0                         116921.0
# 1                  01. Centro     66411.0                          11695.0
# 2                      1001.0       542.0                             72.0
# 3                      1002.0       481.0                            100.0
# 4                      1003.0       884.0                            154.0
# ...                       ...         ...                              ...
# 2460  20. San Blas-Canillejas     59462.0                           4200.0
# 2461                   1096.0       533.0                            101.0
# 2462                   2091.0       486.0                             44.0
# 2463                   5007.0       642.0                             32.0
# 2464                   5025.0       457.0                             35.0
#
# ...
